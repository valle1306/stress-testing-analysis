# %%
import pandas as pd
import os

labels_df = pd.read_csv("C:/Users/lpnhu/Downloads/Stress_Testing_Analysis/preprocessing/stress_labels_all_participants.csv", parse_dates = ["date"])
print("✅ Loaded label file with shape:", labels_df.shape)
labels_df
# Out:
# ✅ Loaded label file with shape: (56, 4)
#     participant_id       date  stress_level  \
# 0                1 2023-12-24             2
# 1                1 2023-12-25             2
# 2                1 2023-12-26             1
# 3                1 2023-12-27             2
# 4                1 2023-12-28             1
# 5                1 2023-12-29             1
# 6                2 2024-01-09             1
# 7                2 2024-01-10             2
# 8                2 2024-01-11             1
# 9                2 2024-01-12             1
# 10               3 2024-02-12             2
# 11               3 2024-02-13             1
# 12               3 2024-02-14             2
# 13               3 2024-02-15             2
# 14               3 2024-02-16             1
# 15               3 2024-02-17             0
# 16               3 2024-02-18             1
# 17               3 2024-02-19             2
# 18               3 2024-02-20             2
# 19               4 2024-03-04             2
# 20               4 2024-03-05             2
# 21               4 2024-03-06             0
# 22               4 2024-03-07             2
# 23               4 2024-03-08             2
# 24               4 2024-03-12             1
# 25               4 2024-03-13             1
# 26               4 2024-03-14             2
# 27               6 2024-04-01             2
# 28               6 2024-04-02             2
# 29               6 2024-04-03             2
# 30               6 2024-04-04             2
# 31               6 2024-04-05             2
# 32               6 2024-04-06             1
# 33               6 2024-04-07             0
# 34               6 2024-04-08             2
# 35               6 2024-04-09             2
# 36               6 2024-04-10             2
# 37               7 2024-04-15             2
# 38               7 2024-04-16             2
# 39               7 2024-04-18             2
# 40               7 2024-04-19             2
# 41               7 2024-04-20             1
# 42               7 2024-04-21             2
# 43               7 2024-04-22             2
# 44               7 2024-04-23             1
# 45               7 2024-04-24             1
# 46               7 2024-04-25             0
# 47               7 2024-04-26             1
# 48               7 2024-04-27             0
# 49               8 2024-05-07             2
# 50               8 2024-05-08             1
# 51               8 2024-05-09             2
# 52               8 2024-05-10             1
# 53               8 2024-05-14             2
# 54               8 2024-05-15             2
# 55               8 2024-05-16             2
#
#                                                 notes
# 0   Night shift in CCU, code stroke, hypertensive ...
# 1   Continued night shift, fatigue, heavy snacking...
# 2   More sugar and overeating, CCU night, but fewe...
# 3   Off day, interrupted sleep by emergency calls,...
# 4   CCU day shift, high caffeine, lots of food, en...
# 5   CCU shift, lifting weights, sugar intake, like...
# 6   Skipped prayer; some irregular intake; no expl...
# 7   Complex ESRD patient; missed prayer; woke up d...
# 8   Clinic confusion; self-reported less stress de...
# 9   Extra patient; late notes; no strong high-stre...
# 10  Clinic AM/PM, multiple patients, preceptor iss...
# 11  Board review stress in AM, errands in PM, mild...
# 12  Woke early, board review, rushed to clinic, st...
# 13  Leg cramps, complicated patient cases, studyin...
# 14  Board review, errands, shopping, mild stress w...
# 15                Snow cleanup, rest, no stress noted
# 16         Buying Tesla added stress despite calm day
# 17  Heavy hospital shift, multiple severe patient ...
# 18  Anxious dreams, floors rotation, high workload...
# 19  MICU night shift, 3 new admissions, code scree...
# 20  Critical labs, missing note, answering emails,...
# 21  Museum day, webinar trouble, Korean BBQ, relax...
# 22  ICU screens, consultants, IR pericardiocentesi...
# 23  Woke at 3am, multiple screens, trauma patient,...
# 24  Inbox overload, played pickleball, some stress...
# 25  Grand rounds, rushed, evening clinic, stress f...
# 26  Overbooked clinic, 5 patients, EKG delays, pre...
# 27  Stress from tossing/turning at night, clinic s...
# 28  Extra-stressful patient (stitches), long day, ...
# 29  Board prep, presentation, full clinic day, nap...
# 30  Clinic patients, bar hopping, sleep disruption...
# 31  Tough patient who got mad and left, multiple p...
# 32  Bridal shower and party, some stress but lower...
# 33  Low activity day, no major clinical stress rec...
# 34  Heart attack admission, multiple patients, hea...
# 35   Multiple admissions, code, steady stress all day
# 36  Rounding, respiratory decompensation, mentor r...
# 37                              Stressful new service
# 38  Near car accident, physical labor moving couch...
# 39  Woke up at 3AM from glucose alarms, crashing p...
# 40  3AM low glucose again, car bump incident, mult...
# 41   Long rounds, traffic, GI distress during workout
# 42  Stuck with patient, family meeting, difficult ...
# 43  Sleep disruption, data access issues, CGM down...
# 44   Test question stress, relaxing walk later in day
# 45               Working on chart of deceased patient
# 46                                            No data
# 47                           Pedicure, annoyed at mom
# 48  Low-stress food log day, no major stress menti...
# 49  Delayed from going home due to brain bleed pat...
# 50  Traded risky stocks, drove to Costco, gym, foo...
# 51  Discharge wrap-up stress, surgery denial, late...
# 52              Still dealing with admissions at 6 PM
# 53  Toilet leaking, rushed to airport, woke up sweaty
# 54               Stress from letter of recommendation
# 55  Triggered psychiatric stress from patient inte...

# %%
labels_df.columns
# Out:
# Index(['participant_id', 'date', 'stress_level', 'notes'], dtype='object')

# %%
profile.columns
# Out:
# Index(['file', 'timestamp_iso', 'accelerometers_std_g', 'missing_value_reason',
#        'counts_x_axis', 'counts_y_axis', 'counts_z_axis', 'vector_magnitude',
#        'activity_class', 'activity_counts', 'activity_intensity',
#        'body_position_left', 'body_position_right', 'eda_scl_usiemens', 'met',
#        'prv_rmssd_ms', 'pulse_rate_bpm', 'respiratory_rate_brpm',
#        'sleep_detection_stage', 'step_counts', 'temperature_celsius',
#        'wearing_detection_percentage', 'hour', 'minute'],
#       dtype='object')

# %%
for pid in [1, 2, 3]:
    df = pd.read_csv(f"C:/Users/lpnhu/Downloads/Stress_Testing_Analysis/na_profiles/participant{pid}_na_summary.csv")
    print(f"\nParticipant {pid} columns:")
    print(df.columns.tolist())
# Out:
# Participant 1 columns:
# ['file', 'timestamp_iso', 'accelerometers_std_g', 'missing_value_reason', 'counts_x_axis', 'counts_y_axis', 'counts_z_axis', 'vector_magnitude', 'activity_class', 'activity_counts', 'activity_intensity', 'body_position_left', 'body_position_right', 'eda_scl_usiemens', 'met', 'pulse_rate_bpm', 'sleep_detection_stage', 'step_counts', 'temperature_celsius', 'wearing_detection_percentage', 'hour', 'minute', 'prv_rmssd_ms', 'respiratory_rate_brpm']
#
# Participant 2 columns:
# ['file', 'timestamp_iso', 'accelerometers_std_g', 'missing_value_reason', 'counts_x_axis', 'counts_y_axis', 'counts_z_axis', 'vector_magnitude', 'activity_class', 'activity_counts', 'activity_intensity', 'body_position_left', 'body_position_right', 'eda_scl_usiemens', 'met', 'prv_rmssd_ms', 'pulse_rate_bpm', 'respiratory_rate_brpm', 'sleep_detection_stage', 'step_counts', 'temperature_celsius', 'wearing_detection_percentage', 'hour', 'minute']
#
# Participant 3 columns:
# ['file', 'timestamp_iso', 'accelerometers_std_g', 'missing_value_reason', 'counts_x_axis', 'counts_y_axis', 'counts_z_axis', 'vector_magnitude', 'activity_class', 'activity_counts', 'activity_intensity', 'body_position_left', 'body_position_right', 'eda_scl_usiemens', 'met', 'prv_rmssd_ms', 'pulse_rate_bpm', 'respiratory_rate_brpm', 'sleep_detection_stage', 'step_counts', 'temperature_celsius', 'wearing_detection_percentage', 'hour', 'minute']

# %%
import pandas as pd
import os

# === CONFIG ===
label_path = "C:/Users/lpnhu/Downloads/Stress_Testing_Analysis/preprocessing/stress_labels_all_participants.csv"
eda_dir = "C:/Users/lpnhu/Downloads/Stress_Testing_Analysis/na_profiles"

# === LOAD STRESS LABELS ===
labels_df = pd.read_csv(label_path, parse_dates=["date"])
print(f"✅ Loaded label file with {len(labels_df)} rows")

# === STORAGE ===
eda_all = []

# === LOOP THROUGH LABELS AND MATCH TO EDA FILE ===
for _, row in labels_df.iterrows():
    pid = row["participant_id"]
    date = row["date"]
    stress = row["stress_level"]
    notes = row["notes"]

    # Build path to EDA file for this participant
    fname = f"participant{pid}_na_summary.csv"
    fpath = os.path.join(eda_dir, fname)
    
    if not os.path.exists(fpath):
        print(f"❌ Missing EDA file: {fname}")
        continue

    eda_df = pd.read_csv(fpath)

    # Extract date from 'file' column (e.g., "cleaned_2023-12-24.csv")
    eda_df["date"] = eda_df["file"].str.extract(r"_(\d{4}-\d{2}-\d{2})\.csv")[0]
    eda_df["date"] = pd.to_datetime(eda_df["date"])

    # Filter for the matching date
    match = eda_df[eda_df["date"] == date]
    if match.empty:
        print(f"⚠️ No EDA summary for PID {pid} on {date.date()}")
        continue

    match = match.copy()
    match["participant_id"] = pid
    match["stress_level"] = stress
    match["notes"] = notes

    eda_all.append(match)

# === CONCATENATE ALL MERGED ROWS ===
eda_merged_df = pd.concat(eda_all, ignore_index=True)
print(f"✅ Final merged dataset shape: {eda_merged_df.shape}")
# Out:
# ✅ Loaded label file with 56 rows
# ✅ Final merged dataset shape: (56, 28)

# %%
eda_merged_df
# Out:
#                       file  timestamp_iso  accelerometers_std_g  \
# 0   cleaned_2023-12-24.csv            0.0                  99.9
# 1   cleaned_2023-12-25.csv            0.0                   5.6
# 2   cleaned_2023-12-26.csv            0.0                  27.2
# 3   cleaned_2023-12-27.csv            0.0                   0.0
# 4   cleaned_2023-12-28.csv            0.0                   6.5
# 5   cleaned_2023-12-29.csv            0.0                  56.5
# 6   cleaned_2024-02-12.csv            0.0                  54.4
# 7   cleaned_2024-02-13.csv            0.0                   0.1
# 8   cleaned_2024-02-14.csv            0.0                   8.3
# 9   cleaned_2024-02-15.csv            0.0                   4.2
# 10  cleaned_2024-02-16.csv            0.0                  25.6
# 11  cleaned_2024-02-17.csv            0.0                  11.8
# 12  cleaned_2024-02-18.csv            0.0                   4.9
# 13  cleaned_2024-02-19.csv            0.0                  12.0
# 14  cleaned_2024-02-20.csv            0.0                   0.0
# 15  cleaned_2024-03-04.csv            0.0                  93.1
# 16  cleaned_2024-03-05.csv            0.0                   0.1
# 17  cleaned_2024-03-06.csv            0.0                  10.5
# 18  cleaned_2024-03-07.csv            0.0                   1.8
# 19  cleaned_2024-03-08.csv            0.0                   0.7
# 20  cleaned_2024-03-12.csv            0.0                  27.4
# 21  cleaned_2024-03-13.csv            0.0                   0.1
# 22  cleaned_2024-03-14.csv            0.0                  12.4
# 23  cleaned_2024-04-01.csv            0.0                   3.3
# 24  cleaned_2024-04-02.csv            0.0                   3.8
# 25  cleaned_2024-04-03.csv            0.0                   1.9
# 26  cleaned_2024-04-04.csv            0.0                   3.9
# 27  cleaned_2024-04-05.csv            0.0                  43.6
# 28  cleaned_2024-04-06.csv            0.0                   6.7
# 29  cleaned_2024-04-07.csv            0.0                   2.4
# 30  cleaned_2024-04-08.csv            0.0                   5.8
# 31  cleaned_2024-04-09.csv            0.0                  10.6
# 32  cleaned_2024-04-10.csv            0.0                  14.4
# 33  cleaned_2024-04-15.csv            0.0                   0.0
# 34  cleaned_2024-04-16.csv            0.0                   1.6
# 35  cleaned_2024-04-18.csv            0.0                   2.6
# 36  cleaned_2024-04-19.csv            0.0                   4.7
# 37  cleaned_2024-04-20.csv            0.0                   4.3
# 38  cleaned_2024-04-21.csv            0.0                   0.9
# 39  cleaned_2024-04-22.csv            0.0                   8.5
# 40  cleaned_2024-04-23.csv            0.0                  13.2
# 41  cleaned_2024-04-24.csv            0.0                   1.0
# 42  cleaned_2024-04-25.csv            0.0                  13.1
# 43  cleaned_2024-04-26.csv            0.0                   0.0
# 44  cleaned_2024-04-27.csv            0.0                  59.4
# 45  cleaned_2024-05-07.csv            0.0                  69.4
# 46  cleaned_2024-05-08.csv            0.0                   0.6
# 47  cleaned_2024-05-09.csv            0.0                   4.2
# 48  cleaned_2024-05-10.csv            0.0                   1.3
# 49  cleaned_2024-05-14.csv            0.0                   7.4
# 50  cleaned_2024-05-15.csv            0.0                   5.2
# 51  cleaned_2024-05-16.csv            0.0                   7.6
#
#     missing_value_reason  counts_x_axis  counts_y_axis  counts_z_axis  \
# 0                    0.1           99.9           99.9           99.9
# 1                   94.4            5.6            5.6            5.6
# 2                   72.8           27.2           27.2           27.2
# 3                    NaN            0.0            0.0            0.0
# 4                   93.5            6.5            6.5            6.5
# 5                   43.5           56.5           56.5           56.5
# 6                   45.6           54.4           54.4           54.4
# 7                   99.9            0.1            0.1            0.1
# 8                   91.7            8.3            8.3            8.3
# 9                   95.8            4.2            4.2            4.2
# 10                  74.4           25.6           25.6           25.6
# 11                  88.2           11.8           11.8           11.8
# 12                  95.1            4.9            4.9            4.9
# 13                  88.0           12.0           12.0           12.0
# 14                   NaN            0.0            0.0            0.0
# 15                   6.9           93.1           93.1           93.1
# 16                  99.9            0.1            0.1            0.1
# 17                  89.5           10.5           10.5           10.5
# 18                  98.2            1.8            1.8            1.8
# 19                  99.3            0.7            0.7            0.7
# 20                  72.6           27.4           27.4           27.4
# 21                  99.9            0.1            0.1            0.1
# 22                  87.6           12.4           12.4           12.4
# 23                  96.7            3.3            3.3            3.3
# 24                  96.2            3.8            3.8            3.8
# 25                  98.1            1.9            1.9            1.9
# 26                  96.1            3.9            3.9            3.9
# 27                  56.4           43.6           43.6           43.6
# 28                  93.3            6.7            6.7            6.7
# 29                  97.6            2.4            2.4            2.4
# 30                  94.2            5.8            5.8            5.8
# 31                  89.4           10.6           10.6           10.6
# 32                  85.6           14.4           14.4           14.4
# 33                   NaN            0.0            0.0            0.0
# 34                  98.4            1.6            1.6            1.6
# 35                  97.4            2.6            2.6            2.6
# 36                  95.3            4.7            4.7            4.7
# 37                  95.7            4.3            4.3            4.3
# 38                  99.1            0.9            0.9            0.9
# 39                  91.5            8.5            8.5            8.5
# 40                  86.8           13.2           13.2           13.2
# 41                  99.0            1.0            1.0            1.0
# 42                  86.9           13.1           13.1           13.1
# 43                   NaN            0.0            0.0            0.0
# 44                  40.6           59.4           59.4           59.4
# 45                  30.6           69.4           69.4           69.4
# 46                  99.4            0.6            0.6            0.6
# 47                  95.8            4.2            4.2            4.2
# 48                  98.7            1.3            1.3            1.3
# 49                  92.6            7.4            7.4            7.4
# 50                  94.8            5.2            5.2            5.2
# 51                  92.4            7.6            7.6            7.6
#
#     vector_magnitude  activity_class  activity_counts  ...  \
# 0               99.9            99.9             99.9  ...
# 1                5.6             5.6              5.6  ...
# 2               27.2            27.2             27.2  ...
# 3                0.0             0.0              0.0  ...
# 4                6.5             6.5              6.5  ...
# 5               56.5            56.5             56.5  ...
# 6               54.4            54.4             54.4  ...
# 7                0.1             0.1              0.1  ...
# 8                8.3             8.3              8.3  ...
# 9                4.2             4.2              4.2  ...
# 10              25.6            25.6             25.6  ...
# 11              11.8            11.8             11.8  ...
# 12               4.9             4.9              4.9  ...
# 13              12.0            12.0             12.0  ...
# 14               0.0             0.0              0.0  ...
# 15              93.1            93.1             93.1  ...
# 16               0.1             0.1              0.1  ...
# 17              10.5            10.5             10.5  ...
# 18               1.8             1.8              1.8  ...
# 19               0.7             0.7              0.7  ...
# 20              27.4            27.4             27.4  ...
# 21               0.1             0.1              0.1  ...
# 22              12.4            12.4             12.4  ...
# 23               3.3             3.3              3.3  ...
# 24               3.8             3.8              3.8  ...
# 25               1.9             1.9              1.9  ...
# 26               3.9             3.9              3.9  ...
# 27              43.6            43.6             43.6  ...
# 28               6.7             6.7              6.7  ...
# 29               2.4             2.4              2.4  ...
# 30               5.8             5.8              5.8  ...
# 31              10.6            10.6             10.6  ...
# 32              14.4            14.4             14.4  ...
# 33               0.0             0.0              0.0  ...
# 34               1.6             1.6              1.6  ...
# 35               2.6             2.6              2.6  ...
# 36               4.7             4.7              4.7  ...
# 37               4.3             4.3              4.3  ...
# 38               0.9             0.9              0.9  ...
# 39               8.5             8.5              8.5  ...
# 40              13.2            13.2             13.2  ...
# 41               1.0             1.0              1.0  ...
# 42              13.1            13.1             13.1  ...
# 43               0.0             0.0              0.0  ...
# 44              59.4            59.4             59.4  ...
# 45              69.4            69.4             69.4  ...
# 46               0.6             0.6              0.6  ...
# 47               4.2             4.2              4.2  ...
# 48               1.3             1.3              1.3  ...
# 49               7.4             7.4              7.4  ...
# 50               5.2             5.2              5.2  ...
# 51               7.6             7.6              7.6  ...
#
#     001_eda_eda_scl_usiemens  001_body-position_body_position_left  \
# 0                        NaN                                   NaN
# 1                        NaN                                   NaN
# 2                       27.2                                  27.2
# 3                        NaN                                   NaN
# 4                        NaN                                   NaN
# 5                        NaN                                   NaN
# 6                        NaN                                   NaN
# 7                        NaN                                   NaN
# 8                        NaN                                   NaN
# 9                        NaN                                   NaN
# 10                       NaN                                   NaN
# 11                       NaN                                   NaN
# 12                       NaN                                   NaN
# 13                       NaN                                   NaN
# 14                       NaN                                   NaN
# 15                       NaN                                   NaN
# 16                       NaN                                   NaN
# 17                       NaN                                   NaN
# 18                       NaN                                   NaN
# 19                       NaN                                   NaN
# 20                       NaN                                   NaN
# 21                       NaN                                   NaN
# 22                       NaN                                   NaN
# 23                       NaN                                   NaN
# 24                       NaN                                   NaN
# 25                       NaN                                   NaN
# 26                       NaN                                   NaN
# 27                       NaN                                   NaN
# 28                       NaN                                   NaN
# 29                       NaN                                   NaN
# 30                       NaN                                   NaN
# 31                       NaN                                   NaN
# 32                       NaN                                   NaN
# 33                       NaN                                   NaN
# 34                       NaN                                   NaN
# 35                       NaN                                   NaN
# 36                       NaN                                   NaN
# 37                       NaN                                   NaN
# 38                       NaN                                   NaN
# 39                       NaN                                   NaN
# 40                       NaN                                   NaN
# 41                       NaN                                   NaN
# 42                       NaN                                   NaN
# 43                       NaN                                   NaN
# 44                       NaN                                   NaN
# 45                       NaN                                   NaN
# 46                       NaN                                   NaN
# 47                       NaN                                   NaN
# 48                       NaN                                   NaN
# 49                       NaN                                   NaN
# 50                       NaN                                   NaN
# 51                       NaN                                   NaN
#
#     001_actigraphy-counts_counts_y_axis  001_pulse-rate_pulse_rate_bpm  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                  27.2                           27.2
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
# 5                                   NaN                            NaN
# 6                                   NaN                            NaN
# 7                                   NaN                            NaN
# 8                                   NaN                            NaN
# 9                                   NaN                            NaN
# 10                                  NaN                            NaN
# 11                                  NaN                            NaN
# 12                                  NaN                            NaN
# 13                                  NaN                            NaN
# 14                                  NaN                            NaN
# 15                                  NaN                            NaN
# 16                                  NaN                            NaN
# 17                                  NaN                            NaN
# 18                                  NaN                            NaN
# 19                                  NaN                            NaN
# 20                                  NaN                            NaN
# 21                                  NaN                            NaN
# 22                                  NaN                            NaN
# 23                                  NaN                            NaN
# 24                                  NaN                            NaN
# 25                                  NaN                            NaN
# 26                                  NaN                            NaN
# 27                                  NaN                            NaN
# 28                                  NaN                            NaN
# 29                                  NaN                            NaN
# 30                                  NaN                            NaN
# 31                                  NaN                            NaN
# 32                                  NaN                            NaN
# 33                                  NaN                            NaN
# 34                                  NaN                            NaN
# 35                                  NaN                            NaN
# 36                                  NaN                            NaN
# 37                                  NaN                            NaN
# 38                                  NaN                            NaN
# 39                                  NaN                            NaN
# 40                                  NaN                            NaN
# 41                                  NaN                            NaN
# 42                                  NaN                            NaN
# 43                                  NaN                            NaN
# 44                                  NaN                            NaN
# 45                                  NaN                            NaN
# 46                                  NaN                            NaN
# 47                                  NaN                            NaN
# 48                                  NaN                            NaN
# 49                                  NaN                            NaN
# 50                                  NaN                            NaN
# 51                                  NaN                            NaN
#
#     001_001_sleep-detection       date  participant_id  stress_level  \
# 0                       NaN 2023-12-24               1             2
# 1                       NaN 2023-12-25               1             2
# 2                      27.2 2023-12-26               1             1
# 3                       NaN 2023-12-27               1             2
# 4                       NaN 2023-12-28               1             1
# 5                       NaN 2023-12-29               1             1
# 6                       NaN 2024-02-12               3             2
# 7                       NaN 2024-02-13               3             1
# 8                       NaN 2024-02-14               3             2
# 9                       NaN 2024-02-15               3             2
# 10                      NaN 2024-02-16               3             1
# 11                      NaN 2024-02-17               3             0
# 12                      NaN 2024-02-18               3             1
# 13                      NaN 2024-02-19               3             2
# 14                      NaN 2024-02-20               3             2
# 15                      NaN 2024-03-04               4             2
# 16                      NaN 2024-03-05               4             2
# 17                      NaN 2024-03-06               4             0
# 18                      NaN 2024-03-07               4             2
# 19                      NaN 2024-03-08               4             2
# 20                      NaN 2024-03-12               4             1
# 21                      NaN 2024-03-13               4             1
# 22                      NaN 2024-03-14               4             2
# 23                      NaN 2024-04-01               6             2
# 24                      NaN 2024-04-02               6             2
# 25                      NaN 2024-04-03               6             2
# 26                      NaN 2024-04-04               6             2
# 27                      NaN 2024-04-05               6             2
# 28                      NaN 2024-04-06               6             1
# 29                      NaN 2024-04-07               6             0
# 30                      NaN 2024-04-08               6             2
# 31                      NaN 2024-04-09               6             2
# 32                      NaN 2024-04-10               6             2
# 33                      NaN 2024-04-15               7             2
# 34                      NaN 2024-04-16               7             2
# 35                      NaN 2024-04-18               7             2
# 36                      NaN 2024-04-19               7             2
# 37                      NaN 2024-04-20               7             1
# 38                      NaN 2024-04-21               7             2
# 39                      NaN 2024-04-22               7             2
# 40                      NaN 2024-04-23               7             1
# 41                      NaN 2024-04-24               7             1
# 42                      NaN 2024-04-25               7             0
# 43                      NaN 2024-04-26               7             1
# 44                      NaN 2024-04-27               7             0
# 45                      NaN 2024-05-07               8             2
# 46                      NaN 2024-05-08               8             1
# 47                      NaN 2024-05-09               8             2
# 48                      NaN 2024-05-10               8             1
# 49                      NaN 2024-05-14               8             2
# 50                      NaN 2024-05-15               8             2
# 51                      NaN 2024-05-16               8             2
#
#                                                 notes  is_stressed
# 0   Night shift in CCU, code stroke, hypertensive ...            1
# 1   Continued night shift, fatigue, heavy snacking...            1
# 2   More sugar and overeating, CCU night, but fewe...            0
# 3   Off day, interrupted sleep by emergency calls,...            1
# 4   CCU day shift, high caffeine, lots of food, en...            0
# 5   CCU shift, lifting weights, sugar intake, like...            0
# 6   Clinic AM/PM, multiple patients, preceptor iss...            1
# 7   Board review stress in AM, errands in PM, mild...            0
# 8   Woke early, board review, rushed to clinic, st...            1
# 9   Leg cramps, complicated patient cases, studyin...            1
# 10  Board review, errands, shopping, mild stress w...            0
# 11                Snow cleanup, rest, no stress noted            0
# 12         Buying Tesla added stress despite calm day            0
# 13  Heavy hospital shift, multiple severe patient ...            1
# 14  Anxious dreams, floors rotation, high workload...            1
# 15  MICU night shift, 3 new admissions, code scree...            1
# 16  Critical labs, missing note, answering emails,...            1
# 17  Museum day, webinar trouble, Korean BBQ, relax...            0
# 18  ICU screens, consultants, IR pericardiocentesi...            1
# 19  Woke at 3am, multiple screens, trauma patient,...            1
# 20  Inbox overload, played pickleball, some stress...            0
# 21  Grand rounds, rushed, evening clinic, stress f...            0
# 22  Overbooked clinic, 5 patients, EKG delays, pre...            1
# 23  Stress from tossing/turning at night, clinic s...            1
# 24  Extra-stressful patient (stitches), long day, ...            1
# 25  Board prep, presentation, full clinic day, nap...            1
# 26  Clinic patients, bar hopping, sleep disruption...            1
# 27  Tough patient who got mad and left, multiple p...            1
# 28  Bridal shower and party, some stress but lower...            0
# 29  Low activity day, no major clinical stress rec...            0
# 30  Heart attack admission, multiple patients, hea...            1
# 31   Multiple admissions, code, steady stress all day            1
# 32  Rounding, respiratory decompensation, mentor r...            1
# 33                              Stressful new service            1
# 34  Near car accident, physical labor moving couch...            1
# 35  Woke up at 3AM from glucose alarms, crashing p...            1
# 36  3AM low glucose again, car bump incident, mult...            1
# 37   Long rounds, traffic, GI distress during workout            0
# 38  Stuck with patient, family meeting, difficult ...            1
# 39  Sleep disruption, data access issues, CGM down...            1
# 40   Test question stress, relaxing walk later in day            0
# 41               Working on chart of deceased patient            0
# 42                                            No data            0
# 43                           Pedicure, annoyed at mom            0
# 44  Low-stress food log day, no major stress menti...            0
# 45  Delayed from going home due to brain bleed pat...            1
# 46  Traded risky stocks, drove to Costco, gym, foo...            0
# 47  Discharge wrap-up stress, surgery denial, late...            1
# 48              Still dealing with admissions at 6 PM            0
# 49  Toilet leaking, rushed to airport, woke up sweaty            1
# 50               Stress from letter of recommendation            1
# 51  Triggered psychiatric stress from patient inte...            1
#
# [52 rows x 123 columns]

# %%
eda_merged_df.columns
# Out:
# Index(['file', 'timestamp_iso', 'accelerometers_std_g', 'missing_value_reason',
#        'counts_x_axis', 'counts_y_axis', 'counts_z_axis', 'vector_magnitude',
#        'activity_class', 'activity_counts', 'activity_intensity',
#        'body_position_left', 'body_position_right', 'eda_scl_usiemens', 'met',
#        'pulse_rate_bpm', 'sleep_detection_stage', 'step_counts',
#        'temperature_celsius', 'wearing_detection_percentage', 'hour', 'minute',
#        'prv_rmssd_ms', 'respiratory_rate_brpm', 'date', 'participant_id',
#        'stress_level', 'notes'],
#       dtype='object')

# %%
eda_merged_df["stress_level"].value_counts()
# Out:
# stress_level
# 2    33
# 1    18
# 0     5
# Name: count, dtype: int64

# %% [markdown]
# * This data is quite imbalanced. Here, we have the option of:
#
#     * Binarize the labels: stressed = 1 if stress_evel == 2, else 0. This will let you frame it as a high stress vs. not high stress classification (which is realisitic for screening use cases).
#     * Drop stress_level == 0: if the 0s are rare and possibly under-annotated (only 5 samples), you can drop them and just model 1 vs 2. This lets you keep multiclass modeling if you believe the distinction between moderate and high stress matters
#     *  Use class balancing in modeling: if you want to keep all levels, but worry about imbalance during training --> use class weight = 'balanced" in models like RandomForestClassifier, LogisticRegression, or XGBoost. OR we use oversampling/ undersampling (e.g SMOTE, RandomOverSampler, etc.)

# %% [markdown]
# # Binarize the imbalanced class to see whether EDA predict stress

# %%
eda_merged_df["is_stressed"] = (eda_merged_df["stress_level"] == 2).astype(int)

# %%
eda_features = [col for col in eda_merged_df.columns if "eda" in col.lower()]
print(eda_features)
# Out:
# ['eda_scl_usiemens']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

X = eda_merged_df[eda_features].fillna(0)
y = eda_merged_df["is_stressed"]

model = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
scores = cross_val_score(model, X, y, cv=5, scoring="accuracy")

print("Cross-validated accuracy:", scores.mean())
# Out:
# Cross-validated accuracy: 0.6924242424242424

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=eda_merged_df, x="is_stressed", y="eda_scl_usiemens")
plt.title("EDA SCL (µS) by Stress Level")
plt.xlabel("High Stress (1) vs Not (0)")
plt.ylabel("EDA SCL (µS)")
plt.show()

# %%
# Compare the result to a dummy variable

from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_val_score

dummy = DummyClassifier(strategy='most_frequent')
baseline_score = cross_val_score(dummy, X, y, cv=5, scoring='accuracy').mean()
print("Baseline accuracy (majority class):", baseline_score)
# Out:
# Baseline accuracy (majority class): 0.5893939393939394

# %%
# ROC Curve, AUC Score

from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_auc_score, roc_curve, RocCurveDisplay

y_probs = cross_val_predict(model, X, y, cv=5, method="predict_proba")[:, 1]
print("AUC:", roc_auc_score(y, y_probs))

fpr, tpr, _ = roc_curve(y, y_probs)
RocCurveDisplay(fpr=fpr, tpr=tpr).plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# AUC: 0.6798418972332015

# %% [markdown]
# ### 🧠 **Can EDA Predict Stress?**
#
# We evaluated whether **electrodermal activity (EDA)** can serve as a standalone predictor of psychological stress in medical trainees, using daily self-reported stress levels as ground truth.
#
# #### 🔍 **Methods**
#
# * We binarized stress labels: `is_stressed = 1` if `stress_level == 2` (high stress), else `0`.
# * Used only one EDA-based feature: `eda_scl_usiemens` (skin conductance level in µS).
# * Trained a **Random Forest classifier** with class weights set to `'balanced'` to account for class imbalance.
# * Performed **5-fold cross-validation** to estimate generalization performance.
# * Compared results against a **dummy classifier** that always predicts the majority class.
# * Assessed discriminatory power using the **ROC curve and AUC score**.
#
# #### 📊 **Results**
#
# * **Cross-validated accuracy**: **0.69**
# * **Baseline accuracy (majority class)**: **0.59**
# * **ROC AUC**: **0.68**
#
# #### 📈 Visual Evidence
#
# * Boxplots show slightly higher median EDA SCL values on high-stress days.
# * The ROC curve shows meaningful separation between stressed and non-stressed days, though not perfect.
#
# #### ✅ **Conclusion**
#
# EDA, even when used alone, has **moderate predictive value** for identifying high-stress days among medical students and residents. With \~10% improvement over the majority-class baseline and AUC nearing 0.70, this suggests that **skin conductance may reflect stress-related physiological arousal**, though **additional biomarkers** or **personalized models** may be needed for stronger predictive performance.

# %%
eda_features_clean = [f for f in eda_features if "missing" not in f.lower()]

# %%
eda_merged_df[eda_features_clean].describe()
# Out:
#        eda_scl_usiemens
# count         56.000000
# mean          14.414286
# std           22.494754
# min            0.000000
# 25%            1.875000
# 50%            6.150000
# 75%           12.100000
# max           99.900000

# %%
import matplotlib.pyplot as plt

plt.bar(["Baseline", "EDA Model"], [0.59, 0.69], color=["gray", "blue"])
plt.ylabel("Accuracy")
plt.title("EDA vs Baseline Accuracy for Predicting High Stress")
plt.ylim(0.5, 0.75)
plt.show()
