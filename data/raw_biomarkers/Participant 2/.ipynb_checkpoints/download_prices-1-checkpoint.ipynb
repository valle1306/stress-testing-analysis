# %%
# !pip install yahoofinancials
# !pip install yfinance

# %%
# https://towardsdatascience.com/a-comprehensive-guide-to-downloading-stock-prices-in-python-2cd93ff821d4
# https://pypi.org/project/yfinance/
import sys

# !{sys.executable} --version
# !{sys.executable} -m pip install yfinance
# !{sys.executable} -m pip install yahoofinancials

import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import matplotlib.pyplot as plt
from IPython.display import display

# %matplotlib inline
# Out:
# Python 3.9.18

# %% [markdown]
# # download Tesla price history

# %%
tsla_df = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2025-01-22', 
                      progress=False, auto_adjust=True)
display(tsla_df.head())
display(tsla_df.tail())
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2019-01-02  20.674667  21.008667  19.920000  20.406668  174879000
# 2019-01-03  20.024000  20.626667  19.825333  20.466667  104478000
# 2019-01-04  21.179333  21.200001  20.181999  20.400000  110911500
# 2019-01-07  22.330667  22.449333  21.183332  21.448000  113268000
# 2019-01-08  22.356667  22.934000  21.801332  22.797333  105127500
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2025-01-14  396.359985  422.640015  394.540009  414.339996  84565000
# 2025-01-15  428.220001  429.799988  405.660004  409.899994  81375500
# 2025-01-16  413.820007  424.000000  409.130005  423.489990  68335200
# 2025-01-17  426.500000  439.739990  419.750000  421.500000  94504200
# 2025-01-21  417.298798  432.984589  406.309998  432.809998  65106295

# %%
import pickle
pickle.dump(tsla_df, open("tesla_data.pkl",'wb'))

# %%
t_data = pickle.load(open("tesla_data.pkl",'rb'))
t_data[:4]
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2019-01-02  20.674667  21.008667  19.920000  20.406668  174879000
# 2019-01-03  20.024000  20.626667  19.825333  20.466667  104478000
# 2019-01-04  21.179333  21.200001  20.181999  20.400000  110911500
# 2019-01-07  22.330667  22.449333  21.183332  21.448000  113268000

# %% [markdown]
# # plot Tesla price history

# %%
ticker = yf.Ticker('TSLA')
tsla_df2 = ticker.history(period="max")
plt.figure(figsize=(18,5))
tsla_df2['Close'].plot(title="TSLA's stock price")
# Out:
# <Axes: title={'center': "TSLA's stock price"}, xlabel='Date'>

# %% [markdown]
# # comparison of closing prices and adjusted closing price

# %%
start_date, tickers = '2010-01-01', ['F','XOM']
prices_df = yf.download(tickers, start=start_date, progress=False, auto_adjust=False)
display(prices_df.head())
prices_df = yf.download(tickers, start=start_date, progress=True, auto_adjust=True)
display(prices_df.head())
display(prices_df.tail())
# Out:
# Price      Adj Close             Close              High               Low  \
# Ticker             F        XOM      F        XOM      F        XOM      F
# Date
# 2010-01-04  5.679181  39.272099  10.28  69.150002  10.28  69.260002  10.05
# 2010-01-05  6.054844  39.425457  10.96  69.419998  11.24  69.449997  10.40
# 2010-01-06  6.281349  39.766201  11.37  70.019997  11.46  70.599998  11.13
# 2010-01-07  6.441560  39.641266  11.66  69.800003  11.69  70.059998  11.32
# 2010-01-08  6.458134  39.482250  11.69  69.519997  11.74  69.750000  11.46
#
# Price                   Open                Volume
# Ticker            XOM      F        XOM          F       XOM
# Date
# 2010-01-04  68.190002  10.17  68.720001   60855800  27809100
# 2010-01-05  68.800003  10.45  69.190002  215620200  30174700
# 2010-01-06  69.339996  11.21  69.449997  200070600  35044700
# 2010-01-07  69.419998  11.46  69.900002  130201700  27192100
# 2010-01-08  69.220001  11.67  69.690002  130463000  24891800
# [*********************100%***********************]  2 of 2 completed
# Price          Close                 High                  Low             \
# Ticker             F        XOM         F        XOM         F        XOM
# Date
# 2010-01-04  5.679179  39.272114  5.679179  39.334586  5.552116  38.726905
# 2010-01-05  6.054846  39.425457  6.209532  39.442494  5.745474  39.073345
# 2010-01-06  6.281351  39.766209  6.331072  40.095607  6.148763  39.380018
# 2010-01-07  6.441560  39.641258  6.458134  39.788916  6.253727  39.425443
# 2010-01-08  6.458134  39.482239  6.485756  39.612864  6.331071  39.311863
#
# Price           Open                Volume
# Ticker             F        XOM          F       XOM
# Date
# 2010-01-04  5.618409  39.027905   60855800  27809100
# 2010-01-05  5.773096  39.294836  215620200  30174700
# 2010-01-06  6.192959  39.442491  200070600  35044700
# 2010-01-07  6.331070  39.698050  130201700  27192100
# 2010-01-08  6.447085  39.578790  130463000  24891800
# Price        Close               High                Low               Open  \
# Ticker           F         XOM      F         XOM      F         XOM      F
# Date
# 2025-01-14   9.780  109.720001   9.82  109.760002   9.68  107.830002   9.78
# 2025-01-15   9.950  111.510002  10.06  111.730003   9.89  109.470001   9.97
# 2025-01-16  10.010  111.320000  10.06  111.690002   9.89  110.550003   9.91
# 2025-01-17  10.180  112.320000  10.21  112.870003  10.04  110.820000  10.08
# 2025-01-21  10.395  111.550003  10.44  112.169998  10.24  111.130501  10.30
#
# Price                     Volume
# Ticker             XOM         F       XOM
# Date
# 2025-01-14  108.790001  45419900  11191200
# 2025-01-15  110.050003  68674400  14521100
# 2025-01-16  111.190002  45770000  10366600
# 2025-01-17  111.029999  60714500  19229100
# 2025-01-21  112.050003  43120739   9575006

# %% [markdown]
# # compare arithmetic versus geometric returns

# %%
from math import log
display(prices_df[:3])

f"Jan 6, 2020 geometric return = {log(8.005848 / 7.717158):0.6f}, arithmetic return = {(8.005848 - 7.717158) /7.717158:0.6f}"
# Out:
# Price          Close                 High                  Low             \
# Ticker             F        XOM         F        XOM         F        XOM
# Date
# 2010-01-04  5.679179  39.272114  5.679179  39.334586  5.552116  38.726905
# 2010-01-05  6.054846  39.425457  6.209532  39.442494  5.745474  39.073345
# 2010-01-06  6.281351  39.766209  6.331072  40.095607  6.148763  39.380018
#
# Price           Open                Volume
# Ticker             F        XOM          F       XOM
# Date
# 2010-01-04  5.618409  39.027905   60855800  27809100
# 2010-01-05  5.773096  39.294836  215620200  30174700
# 2010-01-06  6.192959  39.442491  200070600  35044700
# 'Jan 6, 2020 geometric return = 0.036726, arithmetic return = 0.037409'

# %% [markdown]
# # calculate daily returns

# %%
import numpy as np
np.log(100)-np.log(50)
# Out:
# 0.6931471805599458

# %%
from math import log

prices_f = prices_df[[('Close','F')]].squeeze()   # convert from dataframe to series
returns_f = prices_f.apply(log).diff()              # compute first order differences in the log prices = daily return
returns_f
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.064052
# 2010-01-06    0.036726
# 2010-01-07    0.025186
# 2010-01-08    0.002570
#                 ...
# 2025-01-14    0.007183
# 2025-01-15    0.017233
# 2025-01-16    0.006012
# 2025-01-17    0.016840
# 2025-01-21    0.020900
# Name: (Close, F), Length: 3786, dtype: float64

# %%
plt.figure(figsize=(18,5))
plt.plot(returns_f)
plt.title('Ford', fontsize=25)
plt.xlabel('date', fontsize=25)
plt.ylabel('daily return', fontsize=25)
plt.show()

# %% [markdown]
# # plot distribution of returns

# %%
plt.figure(figsize=(18,5))
plt.hist(returns_f[1:],30)
plt.show()

# %%
import numpy as np
f"mean return = {np.mean(returns_f):0.6f} , return standard deviation = {np.std(returns_f):0.6f}"
# Out:
# 'mean return = 0.000160 , return standard deviation = 0.021560'

# %% [markdown]
# # Exxon returns

# %%
prices_xom = prices_df[[('Close','XOM')]].squeeze()   # convert from dataframe to series
returns_xom = prices_xom.apply(log).diff()              # compute first order differences in the log prices = daily return
returns_xom
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.003897
# 2010-01-06    0.008606
# 2010-01-07   -0.003147
# 2010-01-08   -0.004020
#                 ...
# 2025-01-14    0.003927
# 2025-01-15    0.016183
# 2025-01-16   -0.001705
# 2025-01-17    0.008943
# 2025-01-21   -0.006879
# Name: (Close, XOM), Length: 3786, dtype: float64

# %%
plt.figure(figsize=(18,5))
plt.plot(prices_df[[('Close','XOM')]])
plt.title("XOM")
plt.show()

# %% [markdown]
# # correlations of Ford and Exxon returns

# %%
import numpy as np

plt.figure(figsize=(8,8))
plt.plot(returns_f, returns_xom, 'o')
plt.xlabel('Ford returns', fontsize=25)
plt.ylabel('Exxon returns', fontsize=25)
plt.plot((0,0), (min(returns_xom[1:]), max(returns_xom[1:])),'--',color='purple')
plt.plot((min(returns_f[1:]), max(returns_f[1:])), (0,0),'--',color='red')
plt.show()

np.corrcoef(returns_f[1:], returns_xom[1:])
# Out:
# array([[1.        , 0.44760481],
#        [0.44760481, 1.        ]])

# %%
ticker = "XOM"
stock = yf.Ticker(ticker)
company_info = stock.info

print(f"""ticker: {ticker}
name: {company_info.get('longName','*')}
sector: {company_info.get('sector','*')}
industry: {company_info.get('industry','*')}
""")

company_info
# Out:
# ticker: XOM
# name: Exxon Mobil Corporation
# sector: Energy
# industry: Oil & Gas Integrated
# {'address1': '22777 Springwoods Village Parkway',
#  'city': 'Spring',
#  'state': 'TX',
#  'zip': '77389-1425',
#  'country': 'United States',
#  'phone': '972-940-6000',
#  'website': 'https://corporate.exxonmobil.com',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Exxon Mobil Corporation engages in the exploration and production of crude oil and natural gas in the United States and internationally. It operates through Upstream, Energy Products, Chemical Products, and Specialty Products segments. The Upstream segment explores for and produces crude oil and natural gas. The Energy Products segment offers fuels, aromatics, and catalysts, as well as licensing services. It sells its products under the Exxon, Esso, and Mobil brands. The Chemical Products segment manufactures and markets petrochemicals including olefins, polyolefins, and intermediates. The Specialty Products segment offers performance products, including lubricants, basestocks, waxes, synthetics, elastomers, and resins. The company also involves in the manufacturing, trade, transport, and sale of crude oil, natural gas, petroleum products, petrochemicals, and other specialty products; and pursuit lower-emission business opportunities, including carbon capture and storage, hydrogen, lower-emission fuels, and lithium. Exxon Mobil Corporation was founded in 1870 and is based in Spring, Texas.',
#  'fullTimeEmployees': 62000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Darren W. Woods',
#    'age': 59,
#    'title': 'Chairman of the Board, President & CEO',
#    'yearBorn': 1965,
#    'fiscalYear': 2023,
#    'totalPay': 7797195,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kathryn A. Mikells',
#    'age': 58,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1966,
#    'fiscalYear': 2023,
#    'totalPay': 4781391,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Neil A. Chapman',
#    'age': 62,
#    'title': 'Senior Vice President',
#    'yearBorn': 1962,
#    'fiscalYear': 2023,
#    'totalPay': 5022441,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jack P. Williams Jr.',
#    'age': 60,
#    'title': 'Senior Vice President',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4872389,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Karen T. McKee',
#    'age': 56,
#    'title': 'VP & President of ExxonMobil Product Solutions Company',
#    'yearBorn': 1968,
#    'fiscalYear': 2023,
#    'totalPay': 3949304,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Leonard M. Fox',
#    'age': 60,
#    'title': 'VP, Principal Accounting Officer & Controller',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Marina  Matselinskaya',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey A. Taylor',
#    'age': 59,
#    'title': 'VP, General Counsel and Secretary',
#    'yearBorn': 1965,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Tracey C. Gunnlaugsson',
#    'title': 'President of Global Trading',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Barton P. Cahir',
#    'age': 51,
#    'title': 'Senior Vice President',
#    'yearBorn': 1973,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 9,
#  'boardRisk': 7,
#  'compensationRisk': 9,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 6,
#  'governanceEpochDate': 1735689600,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://ir.exxonmobil.com/phoenix.zhtml?c=115024&p=irol-irhome',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 111.47,
#  'open': 111.2,
#  'dayLow': 110.55,
#  'dayHigh': 111.57,
#  'regularMarketPreviousClose': 111.47,
#  'regularMarketOpen': 111.2,
#  'regularMarketDayLow': 110.55,
#  'regularMarketDayHigh': 111.57,
#  'dividendRate': 3.96,
#  'dividendYield': 0.0355,
#  'exDividendDate': 1731542400,
#  'payoutRatio': 0.4732,
#  'fiveYearAvgDividendYield': 4.98,
#  'beta': 0.88,
#  'trailingPE': 13.854297,
#  'forwardPE': 13.5557,
#  'volume': 4483898,
#  'regularMarketVolume': 4483898,
#  'averageVolume': 15318060,
#  'averageVolume10days': 15827390,
#  'averageDailyVolume10Day': 15827390,
#  'bid': 111.3,
#  'ask': 111.36,
#  'bidSize': 900,
#  'askSize': 800,
#  'marketCap': 488953741312,
#  'fiftyTwoWeekLow': 97.74,
#  'fiftyTwoWeekHigh': 126.34,
#  'priceToSalesTrailing12Months': 1.4221295,
#  'fiftyDayAverage': 113.286,
#  'twoHundredDayAverage': 115.84475,
#  'trailingAnnualDividendRate': 3.8,
#  'trailingAnnualDividendYield': 0.03408989,
#  'currency': 'USD',
#  'enterpriseValue': 513353187328,
#  'profitMargins': 0.09802,
#  'floatShares': 4387227317,
#  'sharesOutstanding': 4395089920,
#  'sharesShort': 40223318,
#  'sharesShortPriorMonth': 41121556,
#  'sharesShortPreviousMonthDate': 1732838400,
#  'dateShortInterest': 1735603200,
#  'sharesPercentSharesOut': 0.0092,
#  'heldPercentInsiders': 0.00059,
#  'heldPercentInstitutions': 0.65487,
#  'shortRatio': 2.38,
#  'shortPercentOfFloat': 0.0092,
#  'impliedSharesOutstanding': 4395089920,
#  'bookValue': 61.112,
#  'priceToBook': 1.8204281,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1727654400,
#  'earningsQuarterlyGrowth': -0.051,
#  'netIncomeToCommon': 33699999744,
#  'trailingEps': 8.03,
#  'forwardEps': 7.87,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 995500800,
#  'enterpriseToRevenue': 1.493,
#  'enterpriseToEbitda': 7.176,
#  '52WeekChange': 0.119176745,
#  'SandP52WeekChange': 0.24251366,
#  'lastDividendValue': 0.99,
#  'lastDividendDate': 1731542400,
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'XOM',
#  'underlyingSymbol': 'XOM',
#  'shortName': 'Exxon Mobil Corporation',
#  'longName': 'Exxon Mobil Corporation',
#  'firstTradeDateEpochUtc': -252322200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '623c29c3-4307-34c2-840f-d89284dd4857',
#  'messageBoardId': 'finmb_406338',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 111.25,
#  'targetHighPrice': 147.0,
#  'targetLowPrice': 105.0,
#  'targetMeanPrice': 129.59386,
#  'targetMedianPrice': 129.0,
#  'recommendationMean': 2.17857,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 26,
#  'totalCash': 26926000128,
#  'totalCashPerShare': 6.126,
#  'ebitda': 71537999872,
#  'totalDebt': 42550001664,
#  'quickRatio': 0.978,
#  'currentRatio': 1.348,
#  'totalRevenue': 343818010624,
#  'debtToEquity': 15.394,
#  'revenuePerShare': 81.881,
#  'returnOnAssets': 0.07083,
#  'returnOnEquity': 0.14513999,
#  'grossProfits': 108422995968,
#  'freeCashflow': 28811499520,
#  'operatingCashflow': 56475000832,
#  'earningsGrowth': -0.147,
#  'revenueGrowth': -0.015,
#  'grossMargins': 0.31535,
#  'ebitdaMargins': 0.20807,
#  'operatingMargins': 0.13274,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 4.2736}
