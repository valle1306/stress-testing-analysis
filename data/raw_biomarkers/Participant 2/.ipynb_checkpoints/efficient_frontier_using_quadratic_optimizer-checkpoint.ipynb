# %%
import sys
# !{sys.executable} --version

# as of 02/02/2024 the clarabel solver is one of the few solvers to import and execute without error
# do not use proxqp or  osqp in Python 3.11.5

# !pip install qpsolvers[open_source_solvers]
# !pip install quadprog
# !pip install qpsolvers[clarabel,daqp,proxqp,scs] 

import math
import numpy as np
from datetime import datetime
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from IPython.display import display
from math import log
from qpsolvers import solve_qp

# %matplotlib inline
# Out:
# Python 3.11.5

# %%
# !pip install --upgrade yfinance
# !pip show yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\lpnhu\anaconda3\lib\site-packages (0.2.40)
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/09/05/28664524fcc67c078313d482bf25fe403e9399130622cfc89e185ec0abf6/yfinance-0.2.54-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.54-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lpnhu\appdata\roaming\python\python311\site-packages (from yfinance) (1.24.4)
# Requirement already satisfied: requests>=2.31 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\lpnhu\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lpnhu\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lpnhu\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lpnhu\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lpnhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lpnhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lpnhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lpnhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\lpnhu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Downloading yfinance-0.2.54-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/108.7 kB ? eta -:--:--
#    ----------------------------------- -- 102.4/108.7 kB 980.4 kB/s eta 0:00:01
#    -------------------------------------- 108.7/108.7 kB 895.2 kB/s eta 0:00:00
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.40
#     Uninstalling yfinance-0.2.40:
#       Successfully uninstalled yfinance-0.2.40
# Successfully installed yfinance-0.2.54
# Name: yfinance
# Version: 0.2.54
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: C:\Users\lpnhu\anaconda3\Lib\site-packages
# Requires: beautifulsoup4, frozendict, multitasking, numpy, pandas, peewee, platformdirs, pytz, requests
# Required-by:

# %% [markdown]
# import numpy as np
# from qpsolvers import solve_qp
#
# M = np.array([[1.0, 2.0, 0.0], [-8.0, 3.0, 2.0], [0.0, 1.0, 1.0]])
# P = M.T @ M  # this is a positive definite matrix
# q = np.array([3.0, 2.0, 3.0]) @ M
# G = np.array([[1.0, 2.0, 1.0], [2.0, 0.0, 1.0], [-1.0, 2.0, -1.0]])
# h = np.array([3.0, 2.0, -2.0])
# A = np.array([1.0, 1.0, 1.0])
# b = np.array([1.0])
#
# x = solve_qp(P, q, G, h, A, b, solver="clarabel") #"proxqp")
# print(f"QP solution: {x = }")

# %%
import warnings
warnings.filterwarnings("ignore")

# https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average

companies = [
    'Apple', 'Amgen', 'American Express', 'Boeing', 'Caterpillar', 'Salesforce', 
    'Cisco', 'Chevron', 'Disney', 'Goldman Sachs', 'Home Depot', 'Honeywell', 
    'IBM', 'Intel', 'Johnson & Johnson', 'JPMorgan Chase', 'Coca-Cola', 'McDonald’s', 
    '3M', 'Merck', 'Microsoft', 'Nike', 'Procter & Gamble', 'Travelers', 'UnitedHealth', 
    'Visa', 'Verizon', 'Walgreens Boots Alliance', 'Walmart'
]

tickers = [
    "AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "GS", 
    "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM", "MRK", 
    "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
]

tickers_df = yf.download(tickers, 
                      start='2024-02-07', 
                      end='2025-02-07', 
                      progress=False, auto_adjust=True)
display(tickers_df.head())
display(tickers_df.tail())

returns = tickers_df['Close'].applymap(log).diff()[1:]

# annualize returns and covariance

stats = returns.agg(['mean', 'std', 'var'])
annual_returns = stats.transpose()['mean'] * 252
annual_covar = returns.cov() * 252
display(stats)
display(annual_covar)
print(annual_returns)
# Out:
# Price            Close                                                  \
# Ticker            AAPL        AMGN         AXP          BA         CAT
# Date
# 2024-02-07  188.279587  287.192291  206.787430  211.919998  318.788757
# 2024-02-08  187.196091  286.202179  208.894058  209.220001  317.222351
# 2024-02-09  187.962479  282.581573  210.140228  209.199997  312.454132
# 2024-02-12  186.270462  285.794495  209.932556  209.330002  316.857788
# 2024-02-13  184.170364  281.960388  207.370941  204.460007  308.198242
#
# Price                                                                  ...  \
# Ticker             CRM       CSCO         CVX         DIS          GS  ...
# Date                                                                   ...
# 2024-02-07  287.235687  48.247330  145.846756   98.249367  377.515076  ...
# 2024-02-08  290.328400  48.421825  147.697052  109.546959  375.933350  ...
# 2024-02-09  289.682007  48.596317  144.801773  107.416275  375.171814  ...
# 2024-02-12  285.724091  48.460602  145.798813  108.308189  383.353638  ...
# 2024-02-13  279.588379  48.121307  144.379959  109.467674  369.792145  ...
#
# Price        Volume                                                         \
# Ticker          MRK      MSFT      NKE       PG      TRV      UNH        V
# Date
# 2024-02-07  6742800  22340500  9447800  7209300  1760600  4109100  4785900
# 2024-02-08  6308300  21225300  6330400  6121600  1745600  3343000  5833400
# 2024-02-09  7891200  22032800  5449000  5978000  1465600  2715400  4618300
# 2024-02-12  5257400  21202900  7501900  5482000  1180800  3194000  3676200
# 2024-02-13  7273400  27824900  6180500  6046800  3570400  3436000  5493800
#
# Price
# Ticker            VZ       WBA       WMT
# Date
# 2024-02-07  21815600   9146300  17082600
# 2024-02-08  19523500   8030900  14427900
# 2024-02-09  18479400   8947700  14329800
# 2024-02-12  15060500   8903000  14795100
# 2024-02-13  14483600  14710900  18574200
#
# [5 rows x 145 columns]
# Price            Close                                                  \
# Ticker            AAPL        AMGN         AXP          BA         CAT
# Date
# 2025-01-31  235.740814  285.420013  317.450012  176.520004  371.440002
# 2025-02-03  227.759583  288.869995  316.529999  175.869995  361.549988
# 2025-02-04  232.544327  289.019989  315.829987  176.229996  361.950012
# 2025-02-05  232.214691  307.809998  320.529999  181.839996  358.850006
# 2025-02-06  232.963867  297.779999  320.149994  184.800003  365.450012
#
# Price                                                                  ...  \
# Ticker             CRM       CSCO         CVX         DIS          GS  ...
# Date                                                                   ...
# 2025-01-31  341.700012  60.599998  149.190002  113.059998  640.400024  ...
# 2025-02-03  339.239990  61.040001  149.339996  114.000000  632.369995  ...
# 2025-02-04  344.140015  61.340000  153.220001  113.300003  634.179993  ...
# 2025-02-05  347.929993  62.570000  152.990005  110.540001  645.450012  ...
# 2025-02-06  330.809998  62.270000  151.899994  112.089996  658.219971  ...
#
# Price         Volume                                                          \
# Ticker           MRK      MSFT       NKE       PG      TRV      UNH        V
# Date
# 2025-01-31  11421600  34223400  13105900  5464700  1463600  4120500  8628100
# 2025-02-03  13363900  25679100  18539200  8668600  1483100  4083600  8004500
# 2025-02-04  50837600  20532100  11943700  6410900  1209700  2869900  5532600
# 2025-02-05  21670600  16316700   9807400  7536800   950300  4621600  4939100
# 2025-02-06  19509700  16309800  16059400  4957900   811000  3926800  4294500
#
# Price
# Ticker            VZ       WBA       WMT
# Date
# 2025-01-31  45185400  91510600  16413900
# 2025-02-03  27967100  31733800  20484200
# 2025-02-04  19190200  23883400  15201200
# 2025-02-05  16830500  18529700  15926700
# 2025-02-06  15370600  13372700  13088500
#
# [5 rows x 145 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 27
#      24 display(tickers_df.head())
#      25 display(tickers_df.tail())
# ---> 27 returns = tickers_df['Close'].applymap(log).diff()[1:]
#      29 # annualize returns and covariance
#      31 stats = returns.agg(['mean', 'std', 'var'])
#
# NameError: name 'log' is not defined

# %% [markdown]
# # Computing the Efficient Frontier
# ## If w is the weight vector of stocks with expected returns μ, then the portfolio return is equal to each stock’s weight multiplied by its return, i.e wTμ. The portfolio risk in terms of the covariance matrix Σ is given by wTΣw. Portfolio optimisation can then be regarded as a convex optimisation problem, and a solution can be found using quadratic programming. If we denote the target return as μ∗, the precise statement of the long-only portfolio optimisation problem is as follows:
#
# ## min_w : $w^T\Sigma w$
#
# ## subject to
#
# ## $$w^T \mu = \mu^*$$
#
# ## $$w^T \textbf{1} = 1$$
#
# ## $$w_i \geq 0$$

# %% [markdown]
# # Calculate the efficient frontier
# ## select a range of target return values ($r^*$)
# ## call the optimizer to find the portfolio with the minimum volatility for each $r^*$ value

# %% [markdown]
# # Quadratic optimizer
# ## https://pypi.org/project/qpsolvers/
#
# minimize     $\frac{1}{2} x^T P x + q^T x$
#
# subject to $$G x <= h $$
# $$A x = b$$
# $$lb <= x <= ub$$

# %% [markdown]
# # Mapping variables in the quadratic optimizer
#
# $$P = \Sigma$$
#
# \begin{equation*}
# q = \begin{bmatrix}
# 0 \\
# 0 \\
# 0
# \end{bmatrix}
# \end{equation*}
#
# $$G, h = None, None$$
#
# \begin{equation*}
# A =  \begin{bmatrix}
# r_0 & r_1 & r_2 \\
# 1 & 1 & 1
# \end{bmatrix}
# \begin{bmatrix}
# w_0 \\
# w_1 \\
# w_2
# \end{bmatrix}=
# \begin{bmatrix}
# r^* \\
# 1
# \end{bmatrix}=b
# \end{equation*}
#
# \begin{equation*}
# lb = \begin{bmatrix}
# 0 \\
# 0 \\
# 0
# \end{bmatrix}<=
# \begin{bmatrix}
# w_0 \\
# w_1 \\
# w_2
# \end{bmatrix}<=
# \begin{bmatrix}
# 1 \\
# 1 \\
# 1
# \end{bmatrix}=ub
# \end{equation*}

# %%
from numpy import array, dot
from qpsolvers import solve_qp

class create_efficient_frontier():
    def __init__(self, returns, covar):
        self.returns = np.array(returns)
        self.covar = np.array(covar)
        self.n =len(self.covar)
        self.tickers = list(returns.index)

    def get_portfolio(self, return_target):
        """for a given target return create lowest variance long-only portfolio"""
        P, q = self.covar, np.array([0.] * self.n)
        G, h = None,None 
        A = np.array([annual_returns, np.array([1.0] * self.n)])
        b = np.array([return_target, 1.0])
        lb, ub = np.array([0.] * self.n),np.array([1.] * self.n)

        self.portfolio = solve_qp(P, q, G, h, A, b, lb, ub, solver='clarabel')  # specified 02/02/2024 'osqp')  # specify solver 02/02/2023
        return {"portfolio":self.portfolio, "risk_ret":self.risk_return()}  # return (allocation , risk-return)

    def risk_return(self):
        """return the risk and return for this portfolio"""
        return np.sqrt(self.portfolio.dot(self.covar.dot(self.portfolio))),\
            self.returns.dot(self.portfolio)

# loop through range of returns to create 20 portfolios on the efficient frontier
    
ef = create_efficient_frontier(annual_returns, annual_covar)
min_return, max_return = min(annual_returns), max(annual_returns)
frontier = np.array([ef.get_portfolio(r)['risk_ret'] 
                     for r in np.linspace(min_return, max_return, 20)]).T

# plot the efficient frontier in the Markowitz risk-return space

plt.plot(frontier[0], frontier[1], 'o-', color='blue') # plot the efficient frontier
for n, r, s in zip(annual_returns.index, annual_returns, np.sqrt(np.diag(annual_covar))):
    plt.plot([s], [r], 'o', color='red')
    plt.text(s+0.005, r, n)
plt.title('efficient frontier using annualized statistics')
plt.xlabel('risk', fontsize=20)
plt.ylabel('return', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\qpsolvers\solve_problem.py:81, in solve_problem(problem, solver, initvals, verbose, **kwargs)
#      80 try:
# ---> 81     return solve_function[solver](problem, **kwargs)
#      82 except KeyError as e:
#
# KeyError: 'clarabel'
#
# The above exception was the direct cause of the following exception:
#
# SolverNotFound                            Traceback (most recent call last)
# Cell In[8], line 31
#      29 ef = create_efficient_frontier(annual_returns, annual_covar)
#      30 min_return, max_return = min(annual_returns), max(annual_returns)
# ---> 31 frontier = np.array([ef.get_portfolio(r)['risk_ret']
#      32                      for r in np.linspace(min_return, max_return, 20)]).T
#      34 # plot the efficient frontier in the Markowitz risk-return space
#      36 plt.plot(frontier[0], frontier[1], 'o-', color='blue') # plot the efficient frontier
#
# Cell In[8], line 31, in <listcomp>(.0)
#      29 ef = create_efficient_frontier(annual_returns, annual_covar)
#      30 min_return, max_return = min(annual_returns), max(annual_returns)
# ---> 31 frontier = np.array([ef.get_portfolio(r)['risk_ret']
#      32                      for r in np.linspace(min_return, max_return, 20)]).T
#      34 # plot the efficient frontier in the Markowitz risk-return space
#      36 plt.plot(frontier[0], frontier[1], 'o-', color='blue') # plot the efficient frontier
#
# Cell In[8], line 19, in create_efficient_frontier.get_portfolio(self, return_target)
#      16 b = np.array([return_target, 1.0])
#      17 lb, ub = np.array([0.] * self.n),np.array([1.] * self.n)
# ---> 19 self.portfolio = solve_qp(P, q, G, h, A, b, lb, ub, solver='clarabel')  # specified 02/02/2024 'osqp')  # specify solver 02/02/2023
#      20 return {"portfolio":self.portfolio, "risk_ret":self.risk_return()}
#
# File ~\anaconda3\Lib\site-packages\qpsolvers\solve_qp.py:135, in solve_qp(P, q, G, h, A, b, lb, ub, solver, initvals, verbose, **kwargs)
#     130     raise NoSolverSelected(
#     131         "Set the `solver` keyword argument to one of the "
#     132         f"available solvers in {available_solvers}"
#     133     )
#     134 problem = Problem(P, q, G, h, A, b, lb, ub)
# --> 135 solution = solve_problem(problem, solver, initvals, verbose, **kwargs)
#     136 return solution.x if solution.found else None
#
# File ~\anaconda3\Lib\site-packages\qpsolvers\solve_problem.py:83, in solve_problem(problem, solver, initvals, verbose, **kwargs)
#      81     return solve_function[solver](problem, **kwargs)
#      82 except KeyError as e:
# ---> 83     raise SolverNotFound(
#      84         f"found solvers {available_solvers} "
#      85         f"but '{solver}' is not one of them; if '{solver}' is "
#      86         f"listed in https://github.com/qpsolvers/qpsolvers#solvers "
#      87         f"you can run ``pip install qpsolvers[{solver}]``"
#      88     ) from e
#
# SolverNotFound: found solvers ['ecos', 'osqp'] but 'clarabel' is not one of them; if 'clarabel' is listed in https://github.com/qpsolvers/qpsolvers#solvers you can run ``pip install qpsolvers[clarabel]``

# %%
print(annual_returns, annual_covar)

# %% [markdown]
# # Portfolios on the efficient frontier

# %%
frontier_pf = pd.DataFrame(np.array([ef.get_portfolio(r)['portfolio'] 
                     for r in np.linspace(min_return, max_return, 20)]),
                           columns=ef.tickers)
display(frontier_pf[-4:])
frontier.T[-4:]

# %%
# create stacked bar plot showing security allocations for portfolios on the efficient frontier 

plt.figure(figsize=(18,4))
ind, width = range(len(frontier_pf)), .5  # number of portfolios, the width of each bar in the plot

# loop through portfolios on the efficient frontier

cumulative = [0.] * frontier_pf.shape[0]
for t in frontier_pf.columns:
    plt.bar(ind, frontier_pf[t], width, bottom=cumulative, label=t)
    cumulative += frontier_pf[t]
    
plt.legend(loc='upper left')
plt.title("asset allocation along the efficient frontier", fontsize=25)
plt.ylabel("percent allocation", fontsize=20)
plt.xlabel("portfolio number on efficient frontier", fontsize=20)
plt.show()

# %% [markdown]
# # locate the min variance portfolio on the efficient frontier

# %%
frontier1 = np.array([ef.get_portfolio(r) for r in np.linspace(min_return, max_return, 20)]).T
frontier1_portfolio = pd.DataFrame([p['portfolio'] for p in frontier1], columns=ef.tickers)
frontier1_rr = pd.DataFrame([p['risk_ret'] for p in frontier1], columns=['risk','return'])

minVar = [i for i,r in enumerate(frontier1_rr['risk']) if r == frontier1_rr['risk'].min()]

print('minimum variance portfolio')
display(frontier1_rr.iloc[minVar, :])
display(frontier1_portfolio.iloc[minVar, :])

# %%
# plot the efficient frontier 

plt.plot(frontier[0], frontier[1], 'o-', color='gray') # plot the efficient frontier
for r, s in zip(annual_returns, np.sqrt(np.diag(annual_covar))):
    plt.plot([s], [r], 'o', color='red', markersize=10) 

# identify the minimum variance portfolio on the plot

mV = frontier1_rr.iloc[minVar, :].values[0]
plt.plot(mV[0],mV[1], 'o', color='blue', markersize=10, label='minVar')

plt.title('efficient frontier using annualized statistics')
plt.xlabel('risk', fontsize=20)
plt.ylabel('return', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# # Component beta
# ## composition and risk-return for minimum variance portfolio

# %%
mv_pf = frontier1_portfolio.iloc[minVar, :]
# pf = np.array(mv_pf)  
portfolio_returns = np.array(returns).dot(np.array(mv_pf).T)

display(mv_pf)
display(frontier1_rr.iloc[minVar, :])

np.std(portfolio_returns) * np.sqrt(252), np.mean(portfolio_returns) * 252

# %% [markdown]
# # compute beta for a stock
# ## regress its returns on the portfolio (in this case min var) returns

# %%
# https://scipy-lectures.org/packages/statistics/auto_examples/plot_regression.html

from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# add column for minimum variance portfolio returns

returns_p = returns.copy()
returns_p['portfolio'] = portfolio_returns
display(returns_p[:5])

# regress the returns for CRM (Salesforce) on the returns for the minimum variance portfolio

selected_ticker = ['CRM','HON','META'][0]

model = ols(f"{selected_ticker} ~ portfolio", returns_p).fit()   # regrssion of returns

print(model.summary())
anova_results = anova_lm(model)

print('\nANOVA results')
print(anova_results)

f"{selected_ticker} beta = {model.params.loc['portfolio']:0.4f}"

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.optimize import minimize

# Define DJ stocks excluding DOW
tickers = [
    "AAPL", "AMGN", "AXP", "BA", "CAT", "CRM", "CSCO", "CVX", "DIS", "GS", 
    "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM", "MRK", 
    "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
]

# Fetch historical data (2017-2025 for VaR calculation)
start_date = "2017-01-01"
end_date = "2025-02-07"
data = yf.download(tickers, start=start_date, end=end_date)["Close"]

# Compute daily returns
returns = data.pct_change().dropna()

# Compute mean returns and covariance matrix
mean_returns = returns.mean()
cov_matrix = returns.cov()

# Define risk-free rate (daily risk-free rate)
risk_free_rate = 0.05 / 252

# Sharpe ratio optimization function
def sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
    portfolio_return = np.dot(weights, mean_returns)
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    return -(portfolio_return - risk_free_rate) / portfolio_volatility  # Negative for minimization

# Constraints and bounds
num_assets = len(tickers)
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})  # Sum of weights must be 1
bounds = tuple((0, 1) for _ in range(num_assets))  # No short selling

# Initial guess
init_guess = np.array(num_assets * [1. / num_assets])

# Optimize
opt_result = minimize(sharpe_ratio, init_guess, args=(mean_returns, cov_matrix, risk_free_rate), 
                      method='SLSQP', bounds=bounds, constraints=constraints)

# Extract optimal weights
optimal_weights = opt_result.x

# Create portfolio DataFrame
portfolio_df = pd.DataFrame({'Ticker': tickers, 'Weight': optimal_weights})

# Filter stocks with weight > 1%
portfolio_df = portfolio_df[portfolio_df['Weight'] > 0.01]
# Out:
# [*********************100%***********************]  29 of 29 completed

# %%
# Calculate position values
investment = 1_000_000
portfolio_df['Position Value'] = portfolio_df['Weight'] * investment

# Correctly map underlying prices
portfolio_df["Underlying Price"] = portfolio_df["Ticker"].map(data.iloc[-1])

# Drop rows where prices are still NaN (shouldn't be needed after fix)
portfolio_df.dropna(subset=["Underlying Price"], inplace=True)

# Compute number of shares
portfolio_df["Shares"] = portfolio_df["Position Value"] / portfolio_df["Underlying Price"]

# Compute Notional Value (Price * Shares)
portfolio_df["Notional Value"] = portfolio_df["Shares"] * portfolio_df["Underlying Price"]

# Display results
print(portfolio_df)
# Out:
#    Ticker    Weight  Position Value  Underlying Price       Shares  \
# 0    AAPL  0.252960   252959.522954        232.963867  1085.831576
# 2     AXP  0.022714    22713.772496        320.149994    70.947284
# 4     CAT  0.118922   118922.489268        365.450012   325.413833
# 20   MSFT  0.151328   151328.219070        415.820007   363.927219
# 24    UNH  0.018407    18407.334461        530.039978    34.728200
# 28    WMT  0.435669   435668.661751        102.849998  4235.961772
#
#     Notional Value
# 0    252959.522954
# 2     22713.772496
# 4    118922.489268
# 20   151328.219070
# 24    18407.334461
# 28   435668.661751

# %%
# Compute 95% Parametric VaR
portfolio_volatility = portfolio_returns.std()
portfolio_mean_return = portfolio_returns.mean()

# Take absolute value to report positive VaR
var_95 = abs(portfolio_mean_return - 1.645 * portfolio_volatility)

# Scale to portfolio value
portfolio_value = 1_000_000  # Investment size
var_95_dollar = var_95 * portfolio_value

# Display results
print(f"95% Parametric VaR: ${var_95_dollar:,.2f}")
# Out:
# 95% Parametric VaR: $18,543.38

# %%
print(data.iloc[-1])  # Check if any tickers have NaN
# Out:
# Ticker
# AAPL    232.963867
# AMGN    297.779999
# AXP     320.149994
# BA      184.800003
# CAT     365.450012
# CRM     330.809998
# CSCO     62.270000
# CVX     151.899994
# DIS     112.089996
# GS      658.219971
# HD      414.160004
# HON     209.820007
# IBM     251.762711
# INTC     19.379999
# JNJ     153.509995
# JPM     276.899994
# KO       63.360001
# MCD     294.359985
# MMM     152.320007
# MRK      88.050003
# MSFT    415.820007
# NKE      71.739998
# PG      168.880005
# TRV     247.639999
# UNH     530.039978
# V       346.896301
# VZ       39.939999
# WBA      10.050000
# WMT     102.849998
# Name: 2025-02-06 00:00:00, dtype: float64

# %% [markdown]
# # Hull

# %% [markdown]
# ## Hull exercise 9.5

# %% [markdown]
# The **LIBOR-OIS spread** measures financial market stress by reflecting the difference between the interbank lending rate (LIBOR) and the nearly risk-free overnight index swap (OIS) rate. A widening spread signals increased credit risk and liquidity concerns among banks, often seen during crises like 2008, while a narrowing spread indicates improved market confidence.

# %% [markdown]
# ## Hull exercise 9.6

# %% [markdown]
# **Duration** measures a bond portfolio’s sensitivity to interest rate changes, estimating the percentage price change for a 1% change in rates. However, it assumes small, parallel shifts in the yield curve and ignores convexity, making it less accurate for large rate changes or non-parallel shifts.

# %% [markdown]
# ## Hull exercise 9.14

# %% [markdown]
# **Duration** measures a portfolio’s overall sensitivity to interest rate changes, while **partial durations** capture sensitivity to specific maturity segments of the yield curve. **DV01 (Dollar Value of 01)** quantifies the dollar impact of a 1 basis point change in yield. Portfolio DV01 is the weighted sum of individual bond DV01s and is related to duration through the bond’s price.
